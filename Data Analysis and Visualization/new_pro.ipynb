# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
path = 'C:\\Users\ABOLARIN BUKOLA\Documents\Data set\T.csv'

# %%
df = pd.read_csv(path)

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df['Dependents'].unique()
# Out:
# array(['0', '1', '2', '3+', nan], dtype=object)

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
df.describe(include = 'all')
# Out:
#          Loan_ID Gender Married Dependents Education Self_Employed  \
# count        614    601     611        599       614           582
# unique       614      2       2          4         2             2
# top     LP002872   Male     Yes          0  Graduate            No
# freq           1    489     398        345       480           500
# mean         NaN    NaN     NaN        NaN       NaN           NaN
# std          NaN    NaN     NaN        NaN       NaN           NaN
# min          NaN    NaN     NaN        NaN       NaN           NaN
# 25%          NaN    NaN     NaN        NaN       NaN           NaN
# 50%          NaN    NaN     NaN        NaN       NaN           NaN
# 75%          NaN    NaN     NaN        NaN       NaN           NaN
# max          NaN    NaN     NaN        NaN       NaN           NaN
#
#         ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count        614.000000         614.000000  592.000000         600.00000
# ...

# %%
df['Total'] = df['ApplicantIncome'] + df['CoapplicantIncome']

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status   Total
# 0             1.0         Urban           Y  5849.0
# 1             1.0         Rural           N  6091.0
# ...

# %%
df1 = df.drop(['Loan_ID', 'ApplicantIncome', 'CoapplicantIncome'], axis = 'columns')

# %%
df1.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  LoanAmount  \
# 0   Male      No          0      Graduate            No         NaN
# 1   Male     Yes          1      Graduate            No       128.0
# 2   Male     Yes          0      Graduate           Yes        66.0
# 3   Male     Yes          0  Not Graduate            No       120.0
# 4   Male      No          0      Graduate            No       141.0
#
#    Loan_Amount_Term  Credit_History Property_Area Loan_Status   Total
# 0             360.0             1.0         Urban           Y  5849.0
# 1             360.0             1.0         Rural           N  6091.0
# 2             360.0             1.0         Urban           Y  3000.0
# 3             360.0             1.0         Urban           Y  4941.0
# 4             360.0             1.0         Urban           Y  6000.0

# %%
df1.isnull().sum()
# Out:
# Gender              13
# Married              3
# Dependents          15
# Education            0
# Self_Employed       32
# LoanAmount          22
# Loan_Amount_Term    14
# Credit_History      50
# Property_Area        0
# Loan_Status          0
# Total                0
# dtype: int64

# %%
df1['Gender'].fillna(df1['Gender'].mode()[0], inplace = True)

# %%
df1.isnull().sum()
# Out:
# Gender               0
# Married              3
# Dependents          15
# Education            0
# Self_Employed       32
# LoanAmount          22
# Loan_Amount_Term    14
# Credit_History      50
# Property_Area        0
# Loan_Status          0
# Total                0
# dtype: int64

# %%
df1['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df1['Married'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df1['Married'].fillna(df1['Married'].mode()[0], inplace = True)

# %%
df1['Married'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df1.isnull().sum()
# Out:
# Gender               0
# Married              0
# Dependents          15
# Education            0
# Self_Employed       32
# LoanAmount          22
# Loan_Amount_Term    14
# Credit_History      50
# Property_Area        0
# Loan_Status          0
# Total                0
# dtype: int64

# %%
df1['Married'].mode()[0]
# Out:
# 'Yes'

# %%
df1['Dependents'].unique()
# Out:
# array(['0', '1', '2', '3+', nan], dtype=object)

# %%
df1['Dependents'].fillna(df1['Dependents'].mode()[0], inplace = True)

# %%
df1['Dependents'].unique()
# Out:
# array(['0', '1', '2', '3+'], dtype=object)

# %%
df1.isnull().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed       32
# LoanAmount          22
# Loan_Amount_Term    14
# Credit_History      50
# Property_Area        0
# Loan_Status          0
# Total                0
# dtype: int64

# %%
df1['Self_Employed'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df1['Self_Employed'].fillna(df1['Self_Employed'].mode()[0], inplace = True)

# %%
df1['LoanAmount'].unique()
# Out:
# array([ nan, 128.,  66., 120., 141., 267.,  95., 158., 168., 349.,  70.,
#        109., 200., 114.,  17., 125., 100.,  76., 133., 115., 104., 315.,
#        116., 112., 151., 191., 122., 110.,  35., 201.,  74., 106., 320.,
#        144., 184.,  80.,  47.,  75., 134.,  96.,  88.,  44., 286.,  97.,
#        135., 180.,  99., 165., 258., 126., 312., 136., 172.,  81., 187.,
#        113., 176., 130., 111., 167., 265.,  50., 210., 175., 131., 188.,
#         25., 137., 160., 225., 216.,  94., 139., 152., 118., 185., 154.,
#         85., 259., 194.,  93., 370., 182., 650., 102., 290.,  84., 242.,
#        129.,  30., 244., 600., 255.,  98., 275., 121.,  63., 700.,  87.,
#        101., 495.,  67.,  73., 260., 108.,  58.,  48., 164., 170.,  83.,
#         90., 166., 124.,  55.,  59., 127., 214., 240.,  72.,  60., 138.,
#         42., 280., 140., 155., 123., 279., 192., 304., 330., 150., 207.,
#        436.,  78.,  54.,  89., 143., 105., 132., 480.,  56., 159., 300.,
# ...

# %%
df1['LoanAmount'].fillna(df1['LoanAmount'].mean(), inplace = True)

# %%
df1['LoanAmount'].mean()
# Out:
# 146.41216216216213

# %%
df1.isnull().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# LoanAmount           0
# Loan_Amount_Term    14
# Credit_History      50
# Property_Area        0
# Loan_Status          0
# Total                0
# dtype: int64

# %%
df1['Loan_Amount_Term'].unique()
# Out:
# array([360., 120., 240.,  nan, 180.,  60., 300., 480.,  36.,  84.,  12.])

# %%
df1['Loan_Amount_Term'].fillna(df1['Loan_Amount_Term'].mean(), inplace = True)

# %%
df1['Credit_History'].unique()
# Out:
# array([ 1.,  0., nan])

# %%
df1['Credit_History'].mean()
# Out:
# 0.8421985815602837

# %%
df1['Credit_History'].fillna(df1['Credit_History'].mode()[0], inplace = True)

# %%
df1.isnull().sum()
# Out:
# Gender              0
# Married             0
# Dependents          0
# Education           0
# Self_Employed       0
# LoanAmount          0
# Loan_Amount_Term    0
# Credit_History      0
# Property_Area       0
# Loan_Status         0
# Total               0
# dtype: int64

# %%
df1.describe(include = 'all')
# Out:
#        Gender Married Dependents Education Self_Employed  LoanAmount  \
# count     614     614        614       614           614  614.000000
# unique      2       2          4         2             2         NaN
# top      Male     Yes          0  Graduate            No         NaN
# freq      502     401        360       480           532         NaN
# mean      NaN     NaN        NaN       NaN           NaN  146.412162
# std       NaN     NaN        NaN       NaN           NaN   84.037468
# min       NaN     NaN        NaN       NaN           NaN    9.000000
# 25%       NaN     NaN        NaN       NaN           NaN  100.250000
# 50%       NaN     NaN        NaN       NaN           NaN  129.000000
# 75%       NaN     NaN        NaN       NaN           NaN  164.750000
# max       NaN     NaN        NaN       NaN           NaN  700.000000
#
#         Loan_Amount_Term  Credit_History Property_Area Loan_Status  \
# count         614.000000      614.000000           614         614
# ...

# %%
df1['LoanAmount'].hist()

# %%
df1['LoanAmount_log'] = np.log(df1['LoanAmount'])

# %%
df1['LoanAmount_log'].hist()

# %%
df1['LoanAmount_log'].describe()
# Out:
# count    614.000000
# mean       4.862066
# std        0.496575
# min        2.197225
# 25%        4.607658
# 50%        4.859812
# 75%        5.104426
# max        6.551080
# Name: LoanAmount_log, dtype: float64

# %%
df1['Loan_Amount_Term'].hist()

# %%
df1['Total'].hist()

# %%
df1['Loan_Amount_Term_log'] = np.log(df1['Loan_Amount_Term'])

# %%
df1['Total_log'] = np.log(df1['Total'])

# %%
df1
# Out:
#      Gender Married Dependents     Education Self_Employed  LoanAmount  \
# 0      Male      No          0      Graduate            No  146.412162
# 1      Male     Yes          1      Graduate            No  128.000000
# 2      Male     Yes          0      Graduate           Yes   66.000000
# 3      Male     Yes          0  Not Graduate            No  120.000000
# 4      Male      No          0      Graduate            No  141.000000
# ..      ...     ...        ...           ...           ...         ...
# 609  Female      No          0      Graduate            No   71.000000
# 610    Male     Yes         3+      Graduate            No   40.000000
# 611    Male     Yes          1      Graduate            No  253.000000
# 612    Male     Yes          2      Graduate            No  187.000000
# 613  Female      No          0      Graduate           Yes  133.000000
#
#      Loan_Amount_Term  Credit_History Property_Area Loan_Status   Total  \
# ...

# %%
df1.drop(['LoanAmount', 'Loan_Amount_Term', 'Total'], axis='columns')
# Out:
#      Gender Married Dependents     Education Self_Employed  Credit_History  \
# 0      Male      No          0      Graduate            No             1.0
# 1      Male     Yes          1      Graduate            No             1.0
# 2      Male     Yes          0      Graduate           Yes             1.0
# 3      Male     Yes          0  Not Graduate            No             1.0
# 4      Male      No          0      Graduate            No             1.0
# ..      ...     ...        ...           ...           ...             ...
# 609  Female      No          0      Graduate            No             1.0
# 610    Male     Yes         3+      Graduate            No             1.0
# 611    Male     Yes          1      Graduate            No             1.0
# 612    Male     Yes          2      Graduate            No             1.0
# 613  Female      No          0      Graduate           Yes             0.0
#
# ...

# %%
d1 = pd.get_dummies(df1['Gender'])
d1.head(3)
# Out:
#    Female  Male
# 0       0     1
# 1       0     1
# 2       0     1

# %%
d2 = pd.get_dummies(df1['Married'])
d2.head(3)
# Out:
#    No  Yes
# 0   1    0
# 1   0    1
# 2   0    1

# %%
d3 = pd.get_dummies(df1['Dependents'])
d3.head(3)
# Out:
#    0  1  2  3+
# 0  1  0  0   0
# 1  0  1  0   0
# 2  1  0  0   0

# %%
d4 = pd.get_dummies(df1['Education'])
d4.head(3)
# Out:
#    Graduate  Not Graduate
# 0         1             0
# 1         1             0
# 2         1             0

# %%
d5 = pd.get_dummies(df1['Self_Employed'])
d5.head(3)
# Out:
#    No  Yes
# 0   1    0
# 1   1    0
# 2   0    1

# %%
d6 = pd.get_dummies(df1['Property_Area'])
d6.head(3)
# Out:
#    Rural  Semiurban  Urban
# 0      0          0      1
# 1      1          0      0
# 2      0          0      1

# %%
d7 = pd.get_dummies(df1['Loan_Status'])
d7.head(3)
# Out:
#    N  Y
# 0  0  1
# 1  1  0
# 2  0  1

# %%
df1['Credit_History'].dtype
# Out:
# dtype('float64')

# %%
df2 = pd.concat([df1, d1.drop('Male', axis = 'columns'), d2.drop('Yes', axis = 'columns'),
                d3.drop('3+', axis = 'columns'), d4.drop('Not Graduate', axis = 'columns'), d5.drop('Yes', axis = 'columns')
                ,d6.drop('Urban', axis = 'columns'), d7.drop('Y', axis = 'columns')], axis = 'columns')

# %% [markdown]
# df2

# %%
df2
# Out:
#      Gender Married Dependents     Education Self_Employed  LoanAmount  \
# 0      Male      No          0      Graduate            No  146.412162
# 1      Male     Yes          1      Graduate            No  128.000000
# 2      Male     Yes          0      Graduate           Yes   66.000000
# 3      Male     Yes          0  Not Graduate            No  120.000000
# 4      Male      No          0      Graduate            No  141.000000
# ..      ...     ...        ...           ...           ...         ...
# 609  Female      No          0      Graduate            No   71.000000
# 610    Male     Yes         3+      Graduate            No   40.000000
# 611    Male     Yes          1      Graduate            No  253.000000
# 612    Male     Yes          2      Graduate            No  187.000000
# 613  Female      No          0      Graduate           Yes  133.000000
#
#      Loan_Amount_Term  Credit_History Property_Area Loan_Status  ...  Female  \
# ...

# %%
df3 = df2.drop(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
               'Property_Area','Loan_Status'], axis = 'columns')

# %%
df3
# Out:
#      LoanAmount  Loan_Amount_Term  Credit_History   Total  LoanAmount_log  \
# 0    146.412162             360.0             1.0  5849.0        4.986426
# 1    128.000000             360.0             1.0  6091.0        4.852030
# 2     66.000000             360.0             1.0  3000.0        4.189655
# 3    120.000000             360.0             1.0  4941.0        4.787492
# 4    141.000000             360.0             1.0  6000.0        4.948760
# ..          ...               ...             ...     ...             ...
# 609   71.000000             360.0             1.0  2900.0        4.262680
# 610   40.000000             180.0             1.0  4106.0        3.688879
# 611  253.000000             360.0             1.0  8312.0        5.533389
# 612  187.000000             360.0             1.0  7583.0        5.231109
# 613  133.000000             360.0             0.0  4583.0        4.890349
#
#      Loan_Amount_Term_log  Total_log  Female  No  0  1  2  Graduate  No  \
# ...

# %%
x = df3.drop('N', axis = 'columns')
x.head(3)
# Out:
#    LoanAmount  Loan_Amount_Term  Credit_History   Total  LoanAmount_log  \
# 0  146.412162             360.0             1.0  5849.0        4.986426
# 1  128.000000             360.0             1.0  6091.0        4.852030
# 2   66.000000             360.0             1.0  3000.0        4.189655
#
#    Loan_Amount_Term_log  Total_log  Female  No  0  1  2  Graduate  No  Rural  \
# 0              5.886104   8.674026       0   1  1  0  0         1   1      0
# 1              5.886104   8.714568       0   0  0  1  0         1   1      1
# 2              5.886104   8.006368       0   0  1  0  0         1   0      0
#
#    Semiurban
# 0          0
# 1          0
# 2          0

# %%
y = df3.N
y.head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    0
# 4    0
# Name: N, dtype: uint8

# %%
df1
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  LoanAmount  \
# 0         1        0           0          0              0  146.412162
# 1         1        1           1          0              0  128.000000
# 2         1        1           0          0              1   66.000000
# 3         1        1           0          1              0  120.000000
# 4         1        0           0          0              0  141.000000
# ..      ...      ...         ...        ...            ...         ...
# 609       0        0           0          0              0   71.000000
# 610       1        1           3          0              0   40.000000
# 611       1        1           1          0              0  253.000000
# 612       1        1           2          0              0  187.000000
# 613       0        0           0          0              1  133.000000
#
#      Loan_Amount_Term  Credit_History  Property_Area  Loan_Status   Total  \
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2, random_state = 10)

# %%
from sklearn.linear_model import LinearRegression
lr_clf = LinearRegression()
lr_clf.fit(x_train, y_train)
lr_clf.score(x_test, y_test)
# Out:
# 0.1978350264766036

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

cv = ShuffleSplit(n_splits = 5, test_size=0.2, random_state=0)

cross_val_score(LinearRegression(),x,y, cv = cv )
# Out:
# array([0.29037009, 0.34735418, 0.25943456, 0.29039717, 0.30255028])

# %%
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor

def find_best_model_using_gridsearchcv(x,y):
    algos = {
        'linear_regression' : {
            'model': LinearRegression(),
            'params': {
                'normalize': [True, False]
            }
        },
        
        'lasso': {
            'model': Lasso(),
            'params': {
                'alpha' : [1,2],
                'selection': ['random', 'cyclic']
            }
        },
        
        'decision_tree': {
            'model': DecisionTreeRegressor(),
            'params': {
                'criterion': ['mse', 'friedman_mse'],
                'splitter': ['best', 'random']
            }
        }
    }
    
    scores = []
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    for algo_name, config in algos.items():
        gs = GridSearchCV(config['model'], config['params'], cv = cv, return_train_score = False)
        gs.fit(x,y)
        scores.append({
            'model': algo_name,
            'best_score': gs.best_score_,
            'best_params': gs.best_params_
        })
        
        
    return pd.DataFrame(scores,columns = ['model', 'best_score', 'best_prams'])
    
find_best_model_using_gridsearchcv(x,y)
# Out:
#                model  best_score  best_prams
# 0  linear_regression    0.298021         NaN
# 1              lasso   -0.016689         NaN
# 2      decision_tree   -0.356314         NaN

# %%
x.columns
# Out:
# Index(['LoanAmount', 'Loan_Amount_Term', 'Credit_History', 'Total',
#        'LoanAmount_log', 'Loan_Amount_Term_log', 'Total_log', 'Female', 'No',
#        '0', '1', '2', 'Graduate', 'No', 'Rural', 'Semiurban'],
#       dtype='object')

# %%
def predict_price(Education, Total, LoanAmount, Credit_History):
    loc_index = np.where(x.columns == Education)[0][0]
            
                        
    X = np.zeros(len(x.columns))
    X[0] = Total
    X[1] = LoanAmount
    X[2] = Credit_History
    if loc_index >= 0:
        X[loc_index] = 1
    return lr_clf.predict([X])[0]

# %%
predict_price('Graduate', 2000,200,1.0)
# Out:
# 2.5371403237000685

# %%
df1
# Out:
#      Gender Married Dependents     Education Self_Employed  LoanAmount  \
# 0      Male      No          0      Graduate            No  146.412162
# 1      Male     Yes          1      Graduate            No  128.000000
# 2      Male     Yes          0      Graduate           Yes   66.000000
# 3      Male     Yes          0  Not Graduate            No  120.000000
# 4      Male      No          0      Graduate            No  141.000000
# ..      ...     ...        ...           ...           ...         ...
# 609  Female      No          0      Graduate            No   71.000000
# 610    Male     Yes         3+      Graduate            No   40.000000
# 611    Male     Yes          1      Graduate            No  253.000000
# 612    Male     Yes          2      Graduate            No  187.000000
# 613  Female      No          0      Graduate           Yes  133.000000
#
#      Loan_Amount_Term  Credit_History Property_Area Loan_Status   Total  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
var_mod = ['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed','Property_Area', 'Loan_Status']
le = LabelEncoder()
for i in var_mod:
    df1[i] = le.fit_transform(df1[i])
df1.dtypes
# Out:
# Gender                    int32
# Married                   int32
# Dependents                int32
# Education                 int32
# Self_Employed             int32
# LoanAmount              float64
# Loan_Amount_Term        float64
# Credit_History          float64
# Property_Area             int32
# Loan_Status               int32
# Total                   float64
# LoanAmount_log          float64
# Loan_Amount_Term_log    float64
# Total_log               float64
# dtype: object

# %%
df1
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  LoanAmount  \
# 0         1        0           0          0              0  146.412162
# 1         1        1           1          0              0  128.000000
# 2         1        1           0          0              1   66.000000
# 3         1        1           0          1              0  120.000000
# 4         1        0           0          0              0  141.000000
# ..      ...      ...         ...        ...            ...         ...
# 609       0        0           0          0              0   71.000000
# 610       1        1           3          0              0   40.000000
# 611       1        1           1          0              0  253.000000
# 612       1        1           2          0              0  187.000000
# 613       0        0           0          0              1  133.000000
#
#      Loan_Amount_Term  Credit_History  Property_Area  Loan_Status   Total  \
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn import metrics

def classification_model(model, data, predictors, outcome, n_splits):
    model.fit(data[predictors], data[outcome])
    
    predictions = model.predict(data[predictors])
    
    accuracy = metrics.accuracy_score(predictions, data[outcome])
    print("Accuracy : %s" % "{0:.3%}".format(accuracy))
    
    
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    error = []
    for train,test in cv:
        train_predictors = (data[predictors].iloc[train,:])
        
        train_target = data[outcome].iloc[train]
        
        model.fit(train_predictors, train_target)
        
        error.append(model.score(data[predictors].iloc[test]))
        
        print("Cross-validation Score : %s" % "{0:.3%}".format(np.mean(error)))
        
        model.fit(data[predictors],data[outcome])

# %%
outcome_var = 'Loan_Status'
model = LogisticRegression()
predictor_var = ['Credit_History']
classification_model(model,df1,predictor_var, outcome_var,5)
# Out:
# Accuracy : 80.945%
# C:\Users\ABOLARIN BUKOLA\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-e61588528eb8> in <module>
#       2 model = LogisticRegression()
#       3 predictor_var = ['Credit_History']
# ----> 4 classification_model(model,df1,predictor_var, outcome_var,5)
#
# <ipython-input-76-69b78fba3dbe> in classification_model(model, data, predictors, outcome, n_splits)
#      16     cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
#      17     error = []
# ---> 18     for train,test in cv:
#      19         train_predictors = (data[predictors].iloc[train,:])
#      20
#
# TypeError: 'ShuffleSplit' object is not iterable

# %%
outcome_var = ['Credit_History', 'Education', 'Married', 'Self_Employed', 'Property_Area']
classification_model(model,df1,predictor_var, outcome_var)

# %%
df1
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  LoanAmount  \
# 0         1        0           0          0              0  146.412162
# 1         1        1           1          0              0  128.000000
# 2         1        1           0          0              1   66.000000
# 3         1        1           0          1              0  120.000000
# 4         1        0           0          0              0  141.000000
# ..      ...      ...         ...        ...            ...         ...
# 609       0        0           0          0              0   71.000000
# 610       1        1           3          0              0   40.000000
# 611       1        1           1          0              0  253.000000
# 612       1        1           2          0              0  187.000000
# 613       0        0           0          0              1  133.000000
#
#      Loan_Amount_Term  Credit_History  Property_Area  Loan_Status   Total  \
# ...

# %%
x = df1.drop('Loan_Status', axis = 'columns')
x.head(3)
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  LoanAmount  \
# 0       1        0           0          0              0  146.412162
# 1       1        1           1          0              0  128.000000
# 2       1        1           0          0              1   66.000000
#
#    Loan_Amount_Term  Credit_History  Property_Area   Total  LoanAmount_log  \
# 0             360.0             1.0              2  5849.0        4.986426
# 1             360.0             1.0              0  6091.0        4.852030
# 2             360.0             1.0              2  3000.0        4.189655
#
#    Loan_Amount_Term_log  Total_log
# 0              5.886104   8.674026
# 1              5.886104   8.714568
# 2              5.886104   8.006368

# %%
y = df1.Loan_Status
y.head(3)
# Out:
# 0    1
# 1    0
# 2    1
# Name: Loan_Status, dtype: int32

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2, random_state = 10)

# %%
from sklearn.linear_model import LinearRegression
lr_clf = LinearRegression()
lr_clf.fit(x_train, y_train)
lr_clf.score(x_test, y_test)
# Out:
# 0.21885199142529943

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

cv = ShuffleSplit(n_splits = 5, test_size=0.2, random_state=0)

cross_val_score(LinearRegression(),x,y, cv = cv )
# Out:
# array([0.26064791, 0.31797564, 0.25390435, 0.26820395, 0.2890184 ])

# %%
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor

def find_best_model_using_gridsearchcv(x,y):
    algos = {
        'linear_regression' : {
            'model': LinearRegression(),
            'params': {
                'normalize': [True, False]
            }
        },
        
        'lasso': {
            'model': Lasso(),
            'params': {
                'alpha' : [1,2],
                'selection': ['random', 'cyclic']
            }
        },
        
        'decision_tree': {
            'model': DecisionTreeRegressor(),
            'params': {
                'criterion': ['mse', 'friedman_mse'],
                'splitter': ['best', 'random']
            }
        }
    }
    
    scores = []
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    for algo_name, config in algos.items():
        gs = GridSearchCV(config['model'], config['params'], cv = cv, return_train_score = False)
        gs.fit(x,y)
        scores.append({
            'model': algo_name,
            'best_score': gs.best_score_,
            'best_params': gs.best_params_
        })
        
        
    return pd.DataFrame(scores,columns = ['model', 'best_score', 'best_prams'])
    
find_best_model_using_gridsearchcv(x,y)
# Out:
#                model  best_score  best_prams
# 0  linear_regression    0.277950         NaN
# 1              lasso   -0.016689         NaN
# 2      decision_tree   -0.316003         NaN

# %%
def predict_price(Education, Total, LoanAmount, Credit_History):
    loc_index = np.where(x.columns == Education)[0][0]
            
                        
    X = np.zeros(len(x.columns))
    X[0] = Total
    X[1] = LoanAmount
    X[2] = Credit_History
    if loc_index >= 0:
        X[loc_index] = 1
    return lr_clf.predict([X])[0]

# %%
predict_price('Graduate', 2000,200,1.0)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-90-3f227b751d84> in <module>
# ----> 1 predict_price('Graduate', 2000,200,1.0)
#
# <ipython-input-89-2d5c5b182442> in predict_price(Education, Total, LoanAmount, Credit_History)
#       1 def predict_price(Education, Total, LoanAmount, Credit_History):
# ----> 2     loc_index = np.where(x.columns == Education)[0][0]
#       3
#       4
#       5     X = np.zeros(len(x.columns))
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
