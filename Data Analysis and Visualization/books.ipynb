# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
PLOT_COLORS = ['#268BD2', "#0052CC", "#FF5722", "#b58900", "#003f5c"]
pd.options.display.float_format = '{:.2f}'.format
sns.set(style = 'ticks')
plt.rc('figure', figsize = (8,5), dpi = 100)
plt.rc('axes', labelpad = 20, facecolor = "#ffffff", linewidth = 0.4, grid = True, labelsize = 14)
plt.rc('patch', linewidth = 0)
plt.rc('xtick.major', width = 0.2)
plt.rc('ytick.major', width = 0.2)
plt.rc('grid', color ='#9E9E9E', linewidth = 0.4)
plt.rc('font', family = 'Arial', weight = '400', size = 10)
plt.rc('text', color = '#282828')
plt.rc('savefig', pad_inches = 0.3, dpi = 300)

# %%
path = 'C:\\Users\ABOLARIN BUKOLA\Documents\Data set\Books.csv\B.csv'

# %%
df = pd.read_csv(path, error_bad_lines = False, sep = r'\s*,\s*')
# Out:
# C:\Users\ABOLARIN BUKOLA\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: ParserWarning:
#
# Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#
# Skipping line 3350: Expected 12 fields in line 3350, saw 13. Error could possibly be due to quotes being ignored when a multi-char delimiter is used.
# Skipping line 4704: Expected 12 fields in line 4704, saw 13. Error could possibly be due to quotes being ignored when a multi-char delimiter is used.
# Skipping line 5879: Expected 12 fields in line 5879, saw 13. Error could possibly be due to quotes being ignored when a multi-char delimiter is used.
# Skipping line 8981: Expected 12 fields in line 8981, saw 13. Error could possibly be due to quotes being ignored when a multi-char delimiter is used.

# %%
df.head()
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                        authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPrÃ©            4.57  0439785960  9780439785969
# 1  J.K. Rowling/Mary GrandPrÃ©            4.49  0439358078  9780439358071
# 2                 J.K. Rowling            4.42  0439554896  9780439554893
# 3  J.K. Rowling/Mary GrandPrÃ©            4.56  043965548X  9780439655484
# 4  J.K. Rowling/Mary GrandPrÃ©            4.78  0439682584  9780439682589
#
#   language_code  num_pages  ratings_count  text_reviews_count  \
# 0           eng        652        2095690               27591
# ...

# %%
df.drop('isbn', axis = 1, inplace = True)

# %%
df.drop('isbn13', axis = 1, inplace = True)

# %%
df.head()
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                        authors  average_rating language_code  num_pages  \
# 0  J.K. Rowling/Mary GrandPrÃ©            4.57           eng        652
# 1  J.K. Rowling/Mary GrandPrÃ©            4.49           eng        870
# 2                 J.K. Rowling            4.42           eng        352
# 3  J.K. Rowling/Mary GrandPrÃ©            4.56           eng        435
# 4  J.K. Rowling/Mary GrandPrÃ©            4.78           eng       2690
#
#    ratings_count  text_reviews_count publication_date        publisher
# 0        2095690               27591        9/16/2006  Scholastic Inc.
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11123 entries, 0 to 11122
# Data columns (total 10 columns):
# bookID                11123 non-null int64
# title                 11123 non-null object
# authors               11123 non-null object
# average_rating        11123 non-null float64
# language_code         11123 non-null object
# num_pages             11123 non-null int64
# ratings_count         11123 non-null int64
# text_reviews_count    11123 non-null int64
# publication_date      11123 non-null object
# publisher             11123 non-null object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 869.1+ KB

# %%
df.describe(include = 'all')
# Out:
#          bookID                   title         authors  average_rating  \
# count  11123.00                   11123           11123        11123.00
# unique      nan                   10348            6639             nan
# top         nan  The Brothers Karamazov  P.G. Wodehouse             nan
# freq        nan                       9              40             nan
# mean   21310.86                     NaN             NaN            3.93
# std    13094.73                     NaN             NaN            0.35
# min        1.00                     NaN             NaN            0.00
# 25%    10277.50                     NaN             NaN            3.77
# 50%    20287.00                     NaN             NaN            3.96
# 75%    32104.50                     NaN             NaN            4.14
# max    45641.00                     NaN             NaN            5.00
#
#        language_code  num_pages  ratings_count  text_reviews_count  \
# ...

# %%
df[df['title'].apply(lambda x: x == 'The Brothers Karamazov')]
# Out:
#       bookID                   title  \
# 1406    4933  The Brothers Karamazov
# 1407    4934  The Brothers Karamazov
# 1408    4935  The Brothers Karamazov
# 1409    4936  The Brothers Karamazov
# 1410    4938  The Brothers Karamazov
# 1411    4940  The Brothers Karamazov
# 1634    5691  The Brothers Karamazov
# 1990    7135  The Brothers Karamazov
# 9352   37058  The Brothers Karamazov
#
#                                                 authors  average_rating  \
# 1406  Fyodor Dostoyevsky/Constance Garnett/Manuel Ko...            4.32
# 1407  Fyodor Dostoyevsky/Fyodor Dostoevsky/Richard P...            4.32
# 1408                    Fyodor Dostoyevsky/David McDuff            4.32
# 1409  Fyodor Dostoyevsky/Richard Pevear/Larissa Volo...            4.32
# 1410  Fyodor Dostoyevsky/Simon Vance/Thomas R. Beyer...            4.32
# 1411  Fyodor Dostoyevsky/Constance Garnett/Maire Jaanus            4.32
# 1634  Fyodor Dostoyevsky/Richard Pevear/Larissa Volo...            4.32
# ...

# %%
df.head()
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                        authors  average_rating language_code  num_pages  \
# 0  J.K. Rowling/Mary GrandPrÃ©            4.57           eng        652
# 1  J.K. Rowling/Mary GrandPrÃ©            4.49           eng        870
# 2                 J.K. Rowling            4.42           eng        352
# 3  J.K. Rowling/Mary GrandPrÃ©            4.56           eng        435
# 4  J.K. Rowling/Mary GrandPrÃ©            4.78           eng       2690
#
#    ratings_count  text_reviews_count publication_date        publisher
# 0        2095690               27591        9/16/2006  Scholastic Inc.
# ...

# %% [markdown]
# ### ANALYSIS QUESTION
# #### 1.The author having the most books to his name
# #### 2.Language code of the books
# #### 3.The author with the most number of pages
# #### 4.Publisher with the most books
# #### 5. When were most books published (day,year, month)
# #### 6.The book,publisher with the most and least average rating
# #### 7.The author with the most average rating
# #### 8.which language code have the most average rating
# #### 9.Does having a large number of page required for high average rating
# #### 10.Same question above but applied to rating count and text reviews count
# #### 11.how are the numerical attributes related(correlated) to each other
# #### 12.the single author and joint author having the most book, the most number of pages, the most average rating

# %%
df_authors = df['authors'].value_counts().to_frame().reset_index().rename(columns = {'index': 'authors', 'authors': 'Number of books'})

# %%
df_author = df_authors[df_authors['Number of books'] > 25]
df_author
# Out:
#             authors  Number of books
# 0    P.G. Wodehouse               40
# 1      Stephen King               40
# 2  Rumiko Takahashi               39
# 3  Orson Scott Card               35
# 4   Agatha Christie               33
# 5     Piers Anthony               30
# 6   Mercedes Lackey               29
# 7      Sandra Brown               29
# 8      Dick Francis               28

# %%
fig,ax = plt.subplots()
sns.barplot(y = 'authors', x = 'Number of books', data = df_author)

# %% [markdown]
# ##### Stephen King and P.G. Wodehouse are the authors with the most books(books They did alone) both having 40 books each. They are followed closely by  Rumiko Takahashi  with 39 books

# %%
value_count = df['language_code'].value_counts().to_dict()
value_count
# Out:
# {'eng': 8908,
#  'en-US': 1408,
#  'spa': 218,
#  'en-GB': 214,
#  'fre': 144,
#  'ger': 99,
#  'jpn': 46,
#  'mul': 19,
#  'zho': 14,
#  'grc': 11,
#  'por': 10,
#  'en-CA': 7,
#  'ita': 5,
#  'lat': 3,
#  'enm': 3,
#  'swe': 2,
#  'rus': 2,
#  'nor': 1,
#  'gla': 1,
#  'nl': 1,
#  'srp': 1,
#  'ara': 1,
#  'ale': 1,
#  'glg': 1,
#  'wel': 1,
#  'msa': 1,
#  'tur': 1}

# %%
df.head()
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                        authors  average_rating language_code  num_pages  \
# 0  J.K. Rowling/Mary GrandPrÃ©            4.57           eng        652
# 1  J.K. Rowling/Mary GrandPrÃ©            4.49           eng        870
# 2                 J.K. Rowling            4.42           eng        352
# 3  J.K. Rowling/Mary GrandPrÃ©            4.56           eng        435
# 4  J.K. Rowling/Mary GrandPrÃ©            4.78           eng       2690
#
#    ratings_count  text_reviews_count publication_date        publisher
# 0        2095690               27591        9/16/2006  Scholastic Inc.
# ...

# %%
df1 = df['language_code'].value_counts().to_frame().reset_index().rename(columns = {'index': 'language', 'language_code': 'No'})

# %%
import plotly.express as px
fig = px.pie(df1, values = 'No', names = 'language', title = 'ttgt', template = 'seaborn')

fig.show()
# Out:
# <div>
#
#
#             <div id="7bf98882-ee50-4903-96fc-ca62f731f94f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7bf98882-ee50-4903-96fc-ca62f731f94f")) {
#                     Plotly.newPlot(
#                         '7bf98882-ee50-4903-96fc-ca62f731f94f',
# ...

# %%
df3 = df[['num_pages', 'authors']]

# %%
df3 = df3.groupby('authors', as_index = False).mean()

# %%
df3
# Out:
#                                                 authors  num_pages
# 0                           A.B. Yehoshua/Hillel Halkin     416.00
# 1          A.D.P. Briggs/Leo Tolstoy/Fyodor Dostoyevsky     256.00
# 2     A.E. Cunningham/Harlan Ellison/Charles F. Mill...     232.00
# 3                                           A.J. Jacobs     389.00
# 4                                            A.M. Homes     256.00
# ...                                                 ...        ...
# 6634                        Ã‰mile Zola/Henri Mitterand     462.00
# 6635        Ã‰mile Zola/Robert Lethbridge/Elinor Dorday     592.00
# 6636               Ã‰mile Zola/Robin Buss/Brian  Nelson     438.00
# 6637                          Ã‰mile Zola/Roger Pearson     528.00
# 6638                             Ã‰ric-Emmanuel Schmitt      85.00
#
# [6639 rows x 2 columns]

# %%
dfp = df['publisher'].value_counts().to_frame().reset_index().rename(columns = {'index': 'publisher', 'publisher': 'No'})

# %%
dfp = dfp[dfp['No'] > 100]
dfp
# Out:
#           publisher   No
# 0           Vintage  318
# 1     Penguin Books  261
# 2  Penguin Classics  184
# 3     Mariner Books  150
# 4  Ballantine Books  144
# 5     HarperCollins  112
# 6  Harper Perennial  112
# 7      Pocket Books  111
# 8            Bantam  110

# %%
fig,ax = plt.subplots()
sns.barplot(y = 'publisher', x = 'No', data = dfp)

# %% [markdown]
# ##### Vintage is the leading publisher when it comes to the most published books with 318 books published

# %%
import datetime
from dateutil import  parser

# %% [markdown]
# df['day'] = df['publication_date'].apply( lambda x : parser.parse(x).strftime("%A"))

# %%
d = -1
for a in df['publication_date']:
    print (parser.parse(str(a)).strftime("%A"))
    d += 1
    print(d)
# Out:
# Saturday
# 0
# Wednesday
# 1
# Saturday
# 2
# Saturday
# 3
# Monday
# 4
# Tuesday
# 5
# Monday
# 6
# Tuesday
# 7
# Tuesday
# 8
# Tuesday
# 9
# Wednesday
# 10
# Wednesday
# 11
# Tuesday
# 12
# Tuesday
# 13
# Tuesday
# 14
# Tuesday
# 15
# Wednesday
# 16
# Tuesday
# 17
# Sunday
# 18
# Wednesday
# 19
# Saturday
# 20
# Tuesday
# 21
# Thursday
# 22
# Friday
# 23
# Tuesday
# 24
# Wednesday
# 25
# Monday
# 26
# Thursday
# 27
# Saturday
# 28
# Sunday
# 29
# Tuesday
# 30
# Tuesday
# 31
# Tuesday
# 32
# Tuesday
# 33
# Thursday
# 34
# Monday
# 35
# Tuesday
# 36
# Tuesday
# 37
# Tuesday
# 38
# Tuesday
# 39
# Tuesday
# 40
# Tuesday
# 41
# Monday
# 42
# Wednesday
# 43
# Tuesday
# 44
# Tuesday
# 45
# Tuesday
# 46
# Saturday
# 47
# Wednesday
# 48
# Monday
# 49
# Friday
# 50
# Friday
# 51
# Sunday
# 52
# Friday
# 53
# Tuesday
# 54
# Wednesday
# 55
# Tuesday
# 56
# Monday
# 57
# Tuesday
# 58
# Friday
# 59
# Monday
# 60
# Monday
# 61
# Thursday
# 62
# Monday
# 63
# Thursday
# 64
# Monday
# 65
# ...

# %%
df.iloc[8177]
# Out:
# bookID                                                            31373
# title                 In Pursuit of the Proper Sinner (Inspector Lyn...
# authors                                               Elizabeth  George
# average_rating                                                     4.10
# language_code                                                       eng
# num_pages                                                           718
# ratings_count                                                     10608
# text_reviews_count                                                  295
# publication_date                                             11/31/2000
# publisher                                                  Bantam Books
# Name: 8177, dtype: object

# %%
df.drop(8177, inplace = True)

# %%
df.reset_index(drop=True, inplace = True)

# %%
d = -1
for a in df['publication_date']:
    print (parser.parse(str(a)).strftime("%A"))
    d += 1
    print(d)
# Out:
# Saturday
# 0
# Wednesday
# 1
# Saturday
# 2
# Saturday
# 3
# Monday
# 4
# Tuesday
# 5
# Monday
# 6
# Tuesday
# 7
# Tuesday
# 8
# Tuesday
# 9
# Wednesday
# 10
# Wednesday
# 11
# Tuesday
# 12
# Tuesday
# 13
# Tuesday
# 14
# Tuesday
# 15
# Wednesday
# 16
# Tuesday
# 17
# Sunday
# 18
# Wednesday
# 19
# Saturday
# 20
# Tuesday
# 21
# Thursday
# 22
# Friday
# 23
# Tuesday
# 24
# Wednesday
# 25
# Monday
# 26
# Thursday
# 27
# Saturday
# 28
# Sunday
# 29
# Tuesday
# 30
# Tuesday
# 31
# Tuesday
# 32
# Tuesday
# 33
# Thursday
# 34
# Monday
# 35
# Tuesday
# 36
# Tuesday
# 37
# Tuesday
# 38
# Tuesday
# 39
# Tuesday
# 40
# Tuesday
# 41
# Monday
# 42
# Wednesday
# 43
# Tuesday
# 44
# Tuesday
# 45
# Tuesday
# 46
# Saturday
# 47
# Wednesday
# 48
# Monday
# 49
# Friday
# 50
# Friday
# 51
# Sunday
# 52
# Friday
# 53
# Tuesday
# 54
# Wednesday
# 55
# Tuesday
# 56
# Monday
# 57
# Tuesday
# 58
# Friday
# 59
# Monday
# 60
# Monday
# 61
# Thursday
# 62
# Monday
# 63
# Thursday
# 64
# Monday
# 65
# ...

# %%
df.iloc[11093]
# Out:
# bookID                                                          45531
# title                     Montaillou  village occitan de 1294 Ã  1324
# authors               Emmanuel Le Roy Ladurie/Emmanuel Le Roy-Ladurie
# average_rating                                                   3.96
# language_code                                                     fre
# num_pages                                                         640
# ratings_count                                                      15
# text_reviews_count                                                  2
# publication_date                                            6/31/1982
# publisher                                              Folio histoire
# Name: 11093, dtype: object

# %%
df.iloc[11094]
# Out:
# bookID                                                            45533
# title                 Montaillou: Cathars and Catholics in a French ...
# authors                            Emmanuel Le Roy Ladurie/Barbara Bray
# average_rating                                                     3.96
# language_code                                                     en-GB
# num_pages                                                           400
# ratings_count                                                        17
# text_reviews_count                                                    2
# publication_date                                              5/29/1980
# publisher                                            Penguin Books Ltd.
# Name: 11094, dtype: object

# %%
df.iloc[11093]
# Out:
# bookID                                                          45531
# title                     Montaillou  village occitan de 1294 Ã  1324
# authors               Emmanuel Le Roy Ladurie/Emmanuel Le Roy-Ladurie
# average_rating                                                   3.96
# language_code                                                     fre
# num_pages                                                         640
# ratings_count                                                      15
# text_reviews_count                                                  2
# publication_date                                            6/31/1982
# publisher                                              Folio histoire
# Name: 11093, dtype: object

# %%
df.drop(11093, inplace = True)

# %%
df.reset_index(drop=True)
# Out:
#        bookID                                              title  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 2           4  Harry Potter and the Chamber of Secrets (Harry...
# 3           5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4           8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...       ...                                                ...
# 11116   45631   Expelled from Eden: A William T. Vollmann Reader
# 11117   45633                        You Bright and Risen Angels
# 11118   45634                    The Ice-Shirt (Seven Dreams #1)
# 11119   45639                                        Poor People
# 11120   45641                        Las aventuras de Tom Sawyer
#
#                                                  authors  average_rating  \
# 0                            J.K. Rowling/Mary GrandPrÃ©            4.57
# ...

# %%
d = -1
for a in df['publication_date']:
    print (parser.parse(str(a)).strftime("%A"))
    d += 1
    print(d)
# Out:
# Saturday
# 0
# Wednesday
# 1
# Saturday
# 2
# Saturday
# 3
# Monday
# 4
# Tuesday
# 5
# Monday
# 6
# Tuesday
# 7
# Tuesday
# 8
# Tuesday
# 9
# Wednesday
# 10
# Wednesday
# 11
# Tuesday
# 12
# Tuesday
# 13
# Tuesday
# 14
# Tuesday
# 15
# Wednesday
# 16
# Tuesday
# 17
# Sunday
# 18
# Wednesday
# 19
# Saturday
# 20
# Tuesday
# 21
# Thursday
# 22
# Friday
# 23
# Tuesday
# 24
# Wednesday
# 25
# Monday
# 26
# Thursday
# 27
# Saturday
# 28
# Sunday
# 29
# Tuesday
# 30
# Tuesday
# 31
# Tuesday
# 32
# Tuesday
# 33
# Thursday
# 34
# Monday
# 35
# Tuesday
# 36
# Tuesday
# 37
# Tuesday
# 38
# Tuesday
# 39
# Tuesday
# 40
# Tuesday
# 41
# Monday
# 42
# Wednesday
# 43
# Tuesday
# 44
# Tuesday
# 45
# Tuesday
# 46
# Saturday
# 47
# Wednesday
# 48
# Monday
# 49
# Friday
# 50
# Friday
# 51
# Sunday
# 52
# Friday
# 53
# Tuesday
# 54
# Wednesday
# 55
# Tuesday
# 56
# Monday
# 57
# Tuesday
# 58
# Friday
# 59
# Monday
# 60
# Monday
# 61
# Thursday
# 62
# Monday
# 63
# Thursday
# 64
# Monday
# 65
# ...

# %%
df['day'] = df['publication_date'].apply( lambda x : parser.parse(x).strftime("%A"))

# %%
dfd = df['day'].value_counts().to_frame().reset_index().rename(columns = {'index': 'day', 'day': 'No'})
dfd
# Out:
#          day    No
# 0    Tuesday  3928
# 1   Thursday  1816
# 2     Monday  1418
# 3  Wednesday  1284
# 4     Friday  1116
# 5   Saturday   825
# 6     Sunday   734

# %%
fig,ax = plt.subplots()
sns.barplot(y = 'day', x = 'No', data = dfd)

# %% [markdown]
# #### Tuesday is the day most books were published

# %%
df['publication_date'] = pd.to_datetime(df['publication_date'])
df['year'] = df['publication_date'].dt.year
dy = df['year'].value_counts().to_frame().reset_index().rename(columns={'index':'Year', 'year': 'No'})
dy.sort_values('Year', ascending = False)
# Out:
#     Year  No
# 85  2020   1
# 54  2019   6
# 57  2018   5
# 50  2017   7
# 53  2016   6
# ..   ...  ..
# 71  1921   2
# 74  1919   1
# 83  1914   1
# 79  1913   1
# 82  1900   1
#
# [87 rows x 2 columns]

# %%
dy = dy[dy['No'] > 500]
dy
# Out:
#    Year    No
# 0  2006  1700
# 1  2005  1260
# 2  2004  1069
# 3  2003   931
# 4  2002   798
# 5  2001   656
# 6  2000   533
# 7  2007   518

# %%
fig,ax = plt.subplots()
sns.barplot(x = 'Year', y = 'No', data = dy)

# %% [markdown]
# ##### The year ranges from 1900 to 2020.2006 is the year most of the books were published

# %%
df['publication_date'] = pd.to_datetime(df['publication_date'])
df['month'] = df['publication_date'].dt.month
dm = df['month'].value_counts().to_frame().reset_index().rename(columns={'index':'month', 'month': 'No'})
dm.sort_values('month', ascending = False)
# Out:
#     month    No
# 11     12   723
# 7      11   846
# 1      10  1212
# 0       9  1278
# 6       8   853
# 9       7   786
# 5       6   879
# 4       5   922
# 3       4   991
# 8       3   832
# 10      2   742
# 2       1  1057

# %%
fig,ax = plt.subplots()
sns.barplot(x = 'month', y = 'No', data = dm)

# %% [markdown]
# ##### We can see that september is the month when most  books where published

# %%
dfbav = df[['title', 'average_rating']]

# %%
dfbav = dfbav.groupby('title', as_index = False).mean()

# %%
dfbav = dfbav.sort_values('average_rating', ascending = False)

# %%
dfbav = dfbav[dfbav['average_rating'] == 5.0]

# %%
fig,ax = plt.subplots(figsize = (5,10))
sns.barplot(y = 'title', x = 'average_rating', data = dfbav)

# %% [markdown]
# ##### The barplot gives the books with the most averge rating with all of them having an average rating of 5.0

# %%
dfpav = df[['publisher', 'average_rating']]

# %%
dfpav = dfpav.groupby('publisher', as_index = False).mean()

# %%
dfpav = dfpav.sort_values('average_rating', ascending = False)

# %%
dfpav = dfpav[dfpav['average_rating'] == 5.0]

# %%
fig,ax = plt.subplots(figsize = (5,10))
sns.barplot(y = 'publisher', x = 'average_rating', data = dfpav)

# %% [markdown]
# ##### This are all the publishers with the most average rating of 5.0

# %%
dfaav = df[['authors', 'average_rating']]

# %%
dfaav = dfaav.groupby('authors', as_index = False).mean()

# %%
dfaav = dfaav.sort_values('average_rating', ascending = False)

# %%
dfaav = dfaav[dfaav['average_rating'] == 5.0]

# %%
fig,ax = plt.subplots(figsize = (5,10))
sns.barplot(y = 'authors', x = 'average_rating', data = dfaav)

# %% [markdown]
# #####  This are the authors with the most average rating of 5.0

# %%
df.loc[(df['average_rating'] == 5.0)]
# Out:
#        bookID                                              title  \
# 624      2034  Comoediae 1: Acharenses/Equites/Nubes/Vespae/P...
# 786      2560                  Willem de Kooning: Late Paintings
# 855      2843  Literature Circle Guide: Bridge to Terabithia:...
# 1243     4287  Middlesex Borough (Images of America: New Jersey)
# 4125    14741  Zone of the Enders: The 2nd Runner Official St...
# 4788    17224  The Diamond Color Meditation: Color Pathway to...
# 4933    17830  Bulgakov's the Master and Margarita: The Text ...
# 5023    18184  The Complete Theory Fun Factory: Music Theory ...
# 5474    19786  The Goon Show  Volume 4: My Knees Have Fallen ...
# 5476    19788  The Goon Show  Volume 11: He's Fallen in the W...
# 5647    20954                                Winchester Shotguns
# 5648    20957  Colossians and Philemon: A Critical and Exeget...
# 6184    23276                          Taxation of Mineral Rents
# ...

# %%
dfaav = df[['language_code', 'average_rating']]

# %%
dfaav = dfaav.groupby('language_code', as_index = False).mean()

# %%
dfaav = dfaav.sort_values('average_rating', ascending = False)
dfaav
# Out:
#    language_code  average_rating
# 25           wel            5.00
# 9            gla            4.47
# 26           zho            4.46
# 24           tur            4.42
# 0            ale            4.36
# 14           lat            4.35
# 13           jpn            4.27
# 20           rus            4.25
# 17            nl            4.18
# 16           mul            4.13
# 15           msa            4.11
# 12           ita            4.08
# 2          en-CA            4.03
# 7            fre            3.97
# 8            ger            3.95
# 19           por            3.95
# 5            eng            3.93
# 21           spa            3.93
# 3          en-GB            3.92
# 4          en-US            3.91
# 6            enm            3.87
# 11           grc            3.71
# 18           nor            3.60
# 1            ara            3.55
# 23           swe            3.46
# 10           glg            3.36
# 22           srp            0.00

# %%
dfaav = dfaav[dfaav['average_rating'] > 4.0]
dfaav
# Out:
#    language_code  average_rating
# 25           wel            5.00
# 9            gla            4.47
# 26           zho            4.46
# 24           tur            4.42
# 0            ale            4.36
# 14           lat            4.35
# 13           jpn            4.27
# 20           rus            4.25
# 17            nl            4.18
# 16           mul            4.13
# 15           msa            4.11
# 12           ita            4.08
# 2          en-CA            4.03

# %%
fig,ax = plt.subplots()
sns.barplot(y = 'language_code', x = 'average_rating', data = dfaav)

# %% [markdown]
# ##### On average wel is the language with the most average rating

# %%
h_labels = [x.replace('_', ' ').title() for x in list(df.select_dtypes(include = ['number', 'bool']).columns.values)]
fig,ax = plt.subplots(figsize = (10,10))
sns.heatmap(df.corr(), annot = True, xticklabels=h_labels, yticklabels= h_labels, cmap = sns.cubehelix_palette(as_cmap = True), ax = ax)

# %%
fig,ax = plt.subplots()
ax.scatter(x = df['ratings_count'], y = df['text_reviews_count'],  color = PLOT_COLORS[2], edgecolors = '#000000', linewidths = 0.5)
ax.set(ylabel = 'text review count', xlabel = 'rating count')
# Out:
# [Text(0, 0.5, 'text review count'), Text(0.5, 0, 'raing count')]

# %% [markdown]
# ##### We can see that text review ang rating count are positively correlated that is a one increases the other decreases

# %%
d = []
e = []
for a in df['authors']:
    b = a.split('/')
    if len(b) == 1:
        d.append(a)
    else:
        e.append(a)
print(len(d) )
# Out:
# 6560

# %%
print(len(set(d )))
# Out:
# 2815

# %%
d = set(d)
e = set(e)
print(d)
# Out:
# {'Garry Wills', 'Natalie Babbitt', 'Donna Tartt', 'Alan Hollinghurst', 'George Orwell', 'Susan  Griffith', 'Andy Warhol', 'Luanne Rice', 'Patrick Lencioni', 'Dai Sijie', 'Robin Cook', 'Hanif Kureishi', 'Radclyffe', 'Anthony Bourdain', 'Richard Olney', 'Steve Turner', 'Donna M. Jackson', 'Jimmy Carter', 'David Noonan', 'Stephen R. Covey', 'Jack Meadows', 'Edward Gibbon', 'Laurence Yep', 'Jill Mansell', 'Anne Tyler', 'Beth A. Jones', 'Elizabeth Peters', 'Alice Sebold', 'James Tiptree Jr.', 'Dani Cavallaro', 'John Lewis Gaddis', 'Mary Higgins Clark', 'Ishmael Beah', 'Aristotle', 'Dave Lakhani', 'Luis VÃ©lez de Guevara', 'Youka Nitta', 'Jon   Stewart', 'Martin E.P. Seligman', 'Michael J. Lyons', 'J.D. Salinger', 'Hiroyuki Morioka', 'Joanne Harris', 'Wanda Sykes', 'Paula J. Caplan', 'Michael D. Lyman', 'Amy Krouse Rosenthal', 'Phil Town', 'Don Ihde', 'Paul Crilley', 'Dashiell Hammett', 'Joanne Fluke', 'David Nasaw', 'Umberto Eco', 'Robert W. Strayer', 'H.W. Brands', 'Richard Hollis', 'Dav
# ...

# %%
df1 = df.loc[df['authors'].isin(d)]

# %%
df2 = df.loc[df['authors'].isin(e)]

# %%
df3 = df1[['authors', 'average_rating']]
df4 = df3.groupby('authors', as_index = False).mean()
df4 = df4.sort_values('average_rating', ascending = False)
df4 = df4[df4['average_rating'] == 5.00]

# %%
fig,ax = plt.subplots()
sns.barplot(x = 'average_rating', y = 'authors', data = df4)

# %% [markdown]
# ##### This are the stand alone authors have the most average rating of 5.00

# %%
df.loc[df['authors'] == 'Elena N. Mahlow']
# Out:
#       bookID                                              title  \
# 4933   17830  Bulgakov's the Master and Margarita: The Text ...
#
#               authors  average_rating language_code  num_pages  ratings_count  \
# 4933  Elena N. Mahlow            5.00           eng        202              4
#
#       text_reviews_count publication_date      publisher        day  year  \
# 4933                   0       1975-01-01  Vantage Press  Wednesday  1975
#
#       month
# 4933      1

# %%
df3 = df2[['authors', 'average_rating']]
df4 = df3.groupby('authors', as_index = False).mean()
df4 = df4.sort_values('average_rating', ascending = False)
df4 = df4[df4['average_rating'] == 5.00]

# %%
fig,ax = plt.subplots()
sns.barplot(x = 'average_rating', y = 'authors', data = df4)

# %% [markdown]
# ##### This are the joint authors having best books of rating 5.0

# %%
df3 = df1[['authors', 'num_pages']]
df4 = df3.groupby('authors', as_index = False).sum()
df4 = df4.sort_values('num_pages', ascending = False)
df4 = df4[df4['num_pages'] > 10000]

# %%
fig,ax = plt.subplots()
sns.barplot(x = 'num_pages', y = 'authors', data = df4)

# %% [markdown]
# ##### Stephen King is the stand alone author with the most number of pages 18219 pages of books

# %%
df3 = df2[['authors', 'num_pages']]
df4 = df3.groupby('authors', as_index = False).sum()
df4 = df4.sort_values('num_pages', ascending = False)
df4 = df4[df4['num_pages'] > 4000]
df4
# Out:
#                                                 authors  num_pages
# 2327                        Margaret Weis/Tracy Hickman       9631
# 1551                 J.R.R. Tolkien/Christopher Tolkien       6959
# 1537                        J.K. Rowling/Mary GrandPrÃ©       5412
# 3771                   Winston S. Churchill/John Keegan       4736
# 1101  Fyodor Dostoyevsky/Richard Pevear/Larissa Volo...       4513
# 2010                    Karen  O'Connor/Larry J. Sabato       4002

# %%
fig,ax = plt.subplots()
sns.barplot(x = 'num_pages', y = 'authors', data = df4)

# %% [markdown]
# ##### Margaret Weis/Tracy Hickman are the authors with the most number of pages 9631 number of pages

# %%
df1['authors'].value_counts()
# Out:
# P.G. Wodehouse         40
# Stephen King           40
# Rumiko Takahashi       39
# Orson Scott Card       35
# Agatha Christie        33
#                        ..
# Arthur Nersesian        1
# Bob Dylan               1
# Amitav Ghosh            1
# Robin Landa             1
# Eliza Gaynor Minden     1
# Name: authors, Length: 2815, dtype: int64

# %%
dm = df1['authors'].value_counts().to_frame().reset_index().rename(columns={'index':'authors', 'authors': 'No'})
dm = dm[dm['No'] > 30]
dm
# Out:
#             authors  No
# 0    P.G. Wodehouse  40
# 1      Stephen King  40
# 2  Rumiko Takahashi  39
# 3  Orson Scott Card  35
# 4   Agatha Christie  33

# %%
fig,ax = plt.subplots()
sns.barplot(x = 'No', y = 'authors', data = dm)

# %% [markdown]
# ##### P.G. Wodehouse and Stephen King are the stand alone authors with the most books, 40 books each. Followed closely by Rumiko Takahashi with 39 books to his name

# %%
df.loc[df['authors'] == 'Stephen King']
# Out:
#       bookID                                           title       authors  \
# 1459    5094   The Drawing of the Three (The Dark Tower  #2)  Stephen King
# 1574    5415                                    'Salem's Lot  Stephen King
# 1575    5417             Carrie / 'Salem's Lot / The Shining  Stephen King
# 1576    5419                                    'Salem's Lot  Stephen King
# 1577    5420                                    'Salem's Lot  Stephen King
# 2843   10566                                   Lisey's Story  Stephen King
# 2847   10574                                The Colorado Kid  Stephen King
# 2849   10579            Everything's Eventual: 14 Dark Tales  Stephen King
# 2851   10583                                    Pet Sematary  Stephen King
# 2859   10603                                            Cujo  Stephen King
# 2864   10613                                     Night Shift  Stephen King
# ...

# %%
dm = df2['authors'].value_counts().to_frame().reset_index().rename(columns={'index':'authors', 'authors': 'No'})
dm = dm[dm['No'] > 10]
dm
# Out:
#                               authors  No
# 0         Margaret Weis/Tracy Hickman  23
# 1            Roald Dahl/Quentin Blake  15
# 2        Francine Pascal/Kate William  15
# 3  J.R.R. Tolkien/Christopher Tolkien  14
# 4        Erin St. Claire/Sandra Brown  13
# 5       Hiromu Arakawa/Akira Watanabe  12
# 6                 Lee Child/Dick Hill  11

# %%
fig,ax = plt.subplots()
sns.barplot(x = 'No', y = 'authors', data = dm)

# %% [markdown]
# ##### Margaret Weis/Tracy Hickman are the joint authors with the most books to their names (23).. Followed by Roald Dahl/Quentin Blake and Francine Pascal/Kate William each with joint authors with 15 books each

# %% [markdown]
# ## CONCLUSION
# #### Check the analysis
