# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
PLOT_COLORS = ['#268BD2', "#0052CC", "#FF5722", "#b58900", "#003f5c"]
pd.options.display.float_format = '{:.2f}'.format
sns.set(style = 'ticks')
plt.rc('figure', figsize = (8,5), dpi = 100)
plt.rc('axes', labelpad = 20, facecolor = "#ffffff", linewidth = 0.4, grid = True, labelsize = 14)
plt.rc('patch', linewidth = 0)
plt.rc('xtick.major', width = 0.2)
plt.rc('ytick.major', width = 0.2)
plt.rc('grid', color ='#9E9E9E', linewidth = 0.4)
plt.rc('font', family = 'Arial', weight = '400', size = 10)
plt.rc('text', color = '#282828')
plt.rc('savefig', pad_inches = 0.3, dpi = 300)

# %%
path = 'C:\\Users\ABOLARIN BUKOLA\Documents\Data set\hotel_bookings.csv\hotel_bookings.csv'

# %%
df = pd.read_csv(path)

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.describe()
# Out:
#        is_canceled  lead_time  arrival_date_year  arrival_date_week_number  \
# count    119390.00  119390.00          119390.00                 119390.00
# mean          0.37     104.01            2016.16                     27.17
# std           0.48     106.86               0.71                     13.61
# min           0.00       0.00            2015.00                      1.00
# 25%           0.00      18.00            2016.00                     16.00
# 50%           0.00      69.00            2016.00                     28.00
# 75%           1.00     160.00            2017.00                     38.00
# max           1.00     737.00            2017.00                     53.00
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# count                  119390.00                119390.00
# mean                       15.80                     0.93
# std                         8.78                     1.00
# ...

# %%
df.describe(include = 'O')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status reservation_status_date
# count        119390        119390             119390                  119390
# unique            3             4                  3                     926
# ...

# %%
df.drop(['arrival_date_week_number'], axis = 1, inplace = True)

# %%
df.head(2)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
#
#    arrival_date_day_of_month  stays_in_weekend_nights  stays_in_week_nights  \
# 0                          1                        0                     0
# 1                          1                        0                     0
#
#    adults  children  ...  deposit_type agent company days_in_waiting_list  \
# 0       2      0.00  ...    No Deposit   nan     nan                    0
# 1       2      0.00  ...    No Deposit   nan     nan                    0
#
#   customer_type  adr  required_car_parking_spaces  total_of_special_requests  \
# 0     Transient 0.00                            0                          0
# 1     Transient 0.00                            0                          0
#
# ...

# %%
df['stay_days'] = df['stays_in_weekend_nights'] + df['stays_in_week_nights']

# %%
df.head(5)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_day_of_month  stays_in_weekend_nights  stays_in_week_nights  \
# 0                          1                        0                     0
# 1                          1                        0                     0
# 2                          1                        0                     1
# 3                          1                        0                     1
# 4                          1                        0                     2
#
# ...

# %%
df['people'] = df['adults'] + df['children'] + df['babies']

# %%
df.head(2)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
#
#    arrival_date_day_of_month  stays_in_weekend_nights  stays_in_week_nights  \
# 0                          1                        0                     0
# 1                          1                        0                     0
#
#    adults  children  ...  company days_in_waiting_list customer_type  adr  \
# 0       2      0.00  ...      nan                    0     Transient 0.00
# 1       2      0.00  ...      nan                    0     Transient 0.00
#
#   required_car_parking_spaces  total_of_special_requests  reservation_status  \
# 0                           0                          0           Check-Out
# 1                           0                          0           Check-Out
#
# ...

# %%
df['distribution_channel'].unique()
# Out:
# array(['Direct', 'Corporate', 'TA/TO', 'Undefined', 'GDS'], dtype=object)

# %%
df[df['market_segment'].apply(lambda x: x == 'TA')]
# Out:
# Empty DataFrame
# Columns: [hotel, is_canceled, lead_time, arrival_date_year, arrival_date_month, arrival_date_day_of_month, stays_in_weekend_nights, stays_in_week_nights, adults, children, babies, meal, country, market_segment, distribution_channel, is_repeated_guest, previous_cancellations, previous_bookings_not_canceled, reserved_room_type, assigned_room_type, booking_changes, deposit_type, agent, company, days_in_waiting_list, customer_type, adr, required_car_parking_spaces, total_of_special_requests, reservation_status, reservation_status_date, stay_days, people]
# Index: []
#
# [0 rows x 33 columns]

# %%
df.drop(['distribution_channel'], axis = 1, inplace = True)

# %%
df.drop(['market_segment'], axis = 1, inplace = True)

# %%
df.drop(['reserved_room_type'], axis = 1, inplace = True)

# %%
df.drop(['assigned_room_type'], axis = 1, inplace = True)

# %%
df.drop(['agent'], axis = 1, inplace = True)

# %%
df.drop(['company'], axis = 1, inplace = True)

# %%
df.drop(['customer_type'], axis = 1, inplace = True)

# %%
df.drop(['required_car_parking_spaces'], axis = 1, inplace = True)

# %%
pd.set_option('display.max_columns', None)
df.head(2)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
#
#    arrival_date_day_of_month  stays_in_weekend_nights  stays_in_week_nights  \
# 0                          1                        0                     0
# 1                          1                        0                     0
#
#    adults  children  babies meal country  is_repeated_guest  \
# 0       2      0.00       0   BB     PRT                  0
# 1       2      0.00       0   BB     PRT                  0
#
#    previous_cancellations  previous_bookings_not_canceled  booking_changes  \
# 0                       0                               0                3
# 1                       0                               0                4
#
#   deposit_type  days_in_waiting_list  adr  total_of_special_requests  \
# ...

# %%
df.describe(include = 'all')
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# count       119390    119390.00  119390.00          119390.00
# unique           2          nan        nan                nan
# top     City Hotel          nan        nan                nan
# freq         79330          nan        nan                nan
# mean           NaN         0.37     104.01            2016.16
# std            NaN         0.48     106.86               0.71
# min            NaN         0.00       0.00            2015.00
# 25%            NaN         0.00      18.00            2016.00
# 50%            NaN         0.00      69.00            2016.00
# 75%            NaN         1.00     160.00            2017.00
# max            NaN         1.00     737.00            2017.00
#
#        arrival_date_month  arrival_date_day_of_month  stays_in_weekend_nights  \
# count              119390                  119390.00                119390.00
# ...

# %%
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# booking_changes                     int64
# deposit_type                       object
# days_in_waiting_list                int64
# adr                               float64
# total_of_special_requests           int64
# reservation_status                 object
# ...

# %%
df.drop(['country'], axis = 1, inplace = True)

# %%
df['people'].unique()
# Out:
# array([ 2.,  1.,  3.,  4.,  5., 12., 40., 26., 50., 27., 55.,  0., 20.,
#         6., 10., nan])

# %%
df['people'].mode()
# Out:
# 0   2.00
# dtype: float64

# %%
df['people'].fillna(2.00, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 24 columns):
# hotel                             119390 non-null object
# is_canceled                       119390 non-null int64
# lead_time                         119390 non-null int64
# arrival_date_year                 119390 non-null int64
# arrival_date_month                119390 non-null object
# arrival_date_day_of_month         119390 non-null int64
# stays_in_weekend_nights           119390 non-null int64
# stays_in_week_nights              119390 non-null int64
# adults                            119390 non-null int64
# children                          119386 non-null float64
# babies                            119390 non-null int64
# meal                              119390 non-null object
# is_repeated_guest                 119390 non-null int64
# previous_cancellations            119390 non-null int64
# previous_bookings_not_canceled    119390 non-null int64
# ...

# %%
rh = df.loc[(df['hotel'] == 'Resort Hotel') & (df['is_canceled'] == 0 )]
ch = df.loc[(df["hotel"] == "City Hotel") & (df["is_canceled"] == 0)]
ch["adr_pp"] = ch["adr"] / (ch["adults"] + ch["children"])
rh
# Out:
# C:\Users\ABOLARIN BUKOLA\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 0      Resort Hotel            0        342               2015
# 1      Resort Hotel            0        737               2015
# 2      Resort Hotel            0          7               2015
# 3      Resort Hotel            0         13               2015
# 4      Resort Hotel            0         14               2015
# ...             ...          ...        ...                ...
# 40055  Resort Hotel            0        212               2017
# ...

# %%
df["adr_pp"] = df["adr"] / (df["adults"] + df["children"])
full_data_guests = df.loc[df["is_canceled"] == 0] # only actual gusts
room_prices_mothly = full_data_guests[["hotel", "arrival_date_month", "adr_pp"]].sort_values("arrival_date_month")

# order by month:
ordered_months = ["January", "February", "March", "April", "May", "June", 
          "July", "August", "September", "October", "November", "December"]
room_prices_mothly["arrival_date_month"] = pd.Categorical(room_prices_mothly["arrival_date_month"], categories=ordered_months, ordered=True)
room_prices_mothly.head()
# Out:
#              hotel arrival_date_month  adr_pp
# 48869   City Hotel              April   81.90
# 110757  City Hotel              April   65.25
# 110758  City Hotel              April   65.25
# 110759  City Hotel              April   45.00
# 110760  City Hotel              April   65.25

# %%
# barplot with standard deviation:
plt.figure(figsize=(12, 8))
sns.lineplot(x = "arrival_date_month", y="adr_pp", hue="hotel", data=room_prices_mothly, 
            hue_order = ["City Hotel", "Resort Hotel"], ci="sd", size="hotel", sizes=(2.5, 2.5))
plt.title("Room price per night and person over the year", fontsize=16)
plt.xlabel("Month", fontsize=16)
plt.xticks(rotation=45)
plt.ylabel("Price [EUR]", fontsize=16)
plt.show()

# %%
resort_guests_monthly = rh.groupby("arrival_date_month")["hotel"].count()
resort_guests_monthly
# Out:
# arrival_date_month
# April        2550
# August       3257
# December     2017
# February     2308
# January      1868
# July         3137
# June         2038
# March        2573
# May          2535
# November     1976
# October      2577
# September    2102
# Name: hotel, dtype: int64

# %%
resort_guest_data = pd.DataFrame({"month": list(resort_guests_monthly.index),
                    "hotel": "Resort hotel", 
                    "guests": list(resort_guests_monthly.values)})

# %%
resort_guests_monthly = rh.groupby("arrival_date_month")["hotel"].count()
city_guests_monthly = ch.groupby("arrival_date_month")["hotel"].count()

resort_guest_data = pd.DataFrame({"month": list(resort_guests_monthly.index),
                    "hotel": "Resort hotel", 
                    "guests": list(resort_guests_monthly.values)})

city_guest_data = pd.DataFrame({"month": list(city_guests_monthly.index),
                    "hotel": "City hotel", 
                    "guests": list(city_guests_monthly.values)})
full_guest_data = pd.concat([resort_guest_data,city_guest_data], ignore_index=True)

# order by month:
ordered_months = ["January", "February", "March", "April", "May", "June", 
          "July", "August", "September", "October", "November", "December"]
full_guest_data["month"] = pd.Categorical(full_guest_data["month"], categories=ordered_months, ordered=True)

# Dataset contains July and August date from 3 years, the other month from 2 years. Normalize data:
full_guest_data.loc[(full_guest_data["month"] == "July") | (full_guest_data["month"] == "August"),"guests"] /= 3

# %% [markdown]
# ### DATA ANALYSIS
# #### 1.How many hotel were cancelled
# #### 2.how many percent of the hotel cancelled were city and resort hotel
# #### 3.most arrival year,month,day
# #### 4.how many stays during the week alone
# #### 5.how many stays during weekends alone
# #### 6.Average day for stays both week and weekend
# #### 7. meal based on the number of people
# #### 8.
# #### 9.

# %%
df['hotel'].value_counts(normalize = True)
# Out:
# City Hotel     0.66
# Resort Hotel   0.34
# Name: hotel, dtype: float64

# %% [markdown]
# #### City hotel takes up 66% of the dataset while Resort hotel 34%

# %%
df1 = df['is_canceled'].value_counts().to_frame().reset_index().rename(columns = {'index' : 'is_canceled', 'is_canceled': 'No'})

# %%
df1.replace(0, 'NO', inplace = True)
df1.replace(1, 'YES', inplace = True)
df1
# Out:
#   is_canceled     No
# 0  NO          75166
# 1  YES         44224

# %%
df['is_canceled'].value_counts(normalize = True)
# Out:
# 0   0.63
# 1   0.37
# Name: is_canceled, dtype: float64

# %%
fig,ax = plt.subplots()
sns.barplot( x= 'is_canceled', y = 'No',  data = df1)

# %% [markdown]
# #### 63% of the booking was NOT canceled while 37% of the booking was canceled

# %%
dy = df['arrival_date_year'].value_counts().to_frame().reset_index().rename(columns = {'index' : 'arrival_date_year', 'arrival_date_year': 'No'})

# %%
fig,ax = plt.subplots()
sns.barplot( x= 'arrival_date_year', y = 'No',  data = dy)

# %% [markdown]
# #### The year ranges from 2015 to 2017. Most of the booking was in the year 2016 while the least was in the year 2015

# %%
dm = df['arrival_date_month'].value_counts().to_frame().reset_index().rename(columns = {'index' : 'arrival_date_month', 'arrival_date_month': 'No'})

# %%
fig,ax = plt.subplots()
sns.barplot( y = 'arrival_date_month', x = 'No',  data = dm)

# %% [markdown]
# ####  The month having the most booking from year 2015 to year 2017 is August why January and December have the least booking

# %%
dd = df['arrival_date_day_of_month'].value_counts().to_frame().reset_index().rename(columns = {'index' : 'arrival_date_day_of_month', 'arrival_date_day_of_month': 'No'})
dd = dd.sort_values('No', ascending = False)
dd
# Out:
#     arrival_date_day_of_month    No
# 0   17                         4406
# 1   5                          4317
# 2   15                         4196
# 3   25                         4160
# 4   26                         4147
# 5   9                          4096
# 6   12                         4087
# 7   16                         4078
# 8   2                          4055
# 9   19                         4052
# 10  20                         4032
# 11  18                         4002
# 12  24                         3993
# 13  28                         3946
# 14  8                          3921
# 15  3                          3855
# 16  30                         3853
# 17  6                          3833
# 18  14                         3819
# 19  27                         3802
# 20  21                         3767
# 21  4                          3763
# 22  13                         3745
# 23  7                          3665
# 24  1                          3626
# ...

# %%
fig,ax = plt.subplots()
sns.barplot( x = 'arrival_date_day_of_month', y = 'No',  data = dd)

# %% [markdown]
# #### Through out the year 2015 to 2017 date 17 is the day most bookings were made

# %%
dg = df[['hotel', 'is_canceled']]

# %%
d = dg.groupby(['hotel'], as_index = False).sum()

# %%
d = d.rename(columns = {'is_canceled': 'is_canceled(YES)' })

# %%
d['is_canceled(YES)'].apply(lambda x: x / 44224)
# Out:
# 0   0.75
# 1   0.25
# Name: is_canceled(YES), dtype: float64

# %%
fig,ax = plt.subplots()
sns.barplot( x = 'hotel', y = 'is_canceled(YES)',  data = d)

# %% [markdown]
# #### 75% of the hotel canceled were city hotel while the remaining 25% were Resort hotel

# %%
df.head(10)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel  0            342        2015               July
# 1  Resort Hotel  0            737        2015               July
# 2  Resort Hotel  0            7          2015               July
# 3  Resort Hotel  0            13         2015               July
# 4  Resort Hotel  0            14         2015               July
# 5  Resort Hotel  0            14         2015               July
# 6  Resort Hotel  0            0          2015               July
# 7  Resort Hotel  0            9          2015               July
# 8  Resort Hotel  1            85         2015               July
# 9  Resort Hotel  1            75         2015               July
#
#    arrival_date_day_of_month  stays_in_weekend_nights  stays_in_week_nights  \
# 0  1                          0                        0
# 1  1                          0                        0
# ...

# %%
df[df['stays_in_weekend_nights'].apply(lambda x : x > 0)]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 20      Resort Hotel  0            37         2015
# 21      Resort Hotel  0            72         2015
# 22      Resort Hotel  0            72         2015
# 23      Resort Hotel  0            72         2015
# 24      Resort Hotel  0            127        2015
# ...              ... ..            ...         ...
# 119385  City Hotel    0            23         2017
# 119386  City Hotel    0            102        2017
# 119387  City Hotel    0            34         2017
# 119388  City Hotel    0            109        2017
# 119389  City Hotel    0            205        2017
#
#        arrival_date_month  arrival_date_day_of_month  stays_in_weekend_nights  \
# 20      July               1                          1
# 21      July               1                          2
# 22      July               1                          2
# 23      July               1                          2
# ...

# %%
df['nights'] = df['stays_in_weekend_nights'] + df['stays_in_week_nights']

# %%
df.drop('stays_in_week_nights', axis = 1, inplace = True)

# %%
df.drop('stays_in_weekend_nights', axis = 1, inplace = True)

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel  0            342        2015               July
# 1  Resort Hotel  0            737        2015               July
# 2  Resort Hotel  0            7          2015               July
# 3  Resort Hotel  0            13         2015               July
# 4  Resort Hotel  0            14         2015               July
#
#    arrival_date_day_of_month  adults  children  babies meal  \
# 0  1                          2      0.00       0       BB
# 1  1                          2      0.00       0       BB
# 2  1                          1      0.00       0       BB
# 3  1                          1      0.00       0       BB
# 4  1                          2      0.00       0       BB
#
#    is_repeated_guest  previous_cancellations  previous_bookings_not_canceled  \
# 0  0                  0                       0
# 1  0                  0                       0
# ...

# %%
df['meal'].unique()
# Out:
# array(['BB', 'FB', 'HB', 'SC', 'Undefined'], dtype=object)

# %%
df['meal'].value_counts()
# Out:
# BB           92310
# HB           14463
# SC           10650
# Undefined    1169
# FB           798
# Name: meal, dtype: int64

# %%
rg = df[['is_repeated_guest', 'hotel']]

# %%
r = rg.groupby('hotel', as_index = False).sum()
r
# Out:
#           hotel  is_repeated_guest
# 0  City Hotel    2032
# 1  Resort Hotel  1778

# %%
r['is_repeated_guest'].apply(lambda x: x / 3800)
# Out:
# 0   0.53
# 1   0.47
# Name: is_repeated_guest, dtype: float64

# %%
fig,ax = plt.subplots()
sns.barplot( x = 'hotel', y = 'is_repeated_guest',  data = r)

# %% [markdown]
# #### 53% of repeated guest was that of City Hotel while 47% was that of Resort hotel

# %%
rg = df[['previous_cancellations', 'hotel']]
r = rg.groupby('hotel', as_index = False).sum()
r
# Out:
#           hotel  previous_cancellations
# 0  City Hotel    6326
# 1  Resort Hotel  4075

# %%
r['previous_cancellations'].apply(lambda x: x / 10401)
# Out:
# 0   0.61
# 1   0.39
# Name: previous_cancellations, dtype: float64

# %%
fig,ax = plt.subplots()
sns.barplot( x = 'hotel', y = 'previous_cancellations',  data = r)

# %% [markdown]
# #### 61% of city hotel have a record of previous_cancellations while Resort hotel have a record of 39% of previous_cancellations

# %%
rg = df[['previous_bookings_not_canceled', 'hotel']]
r = rg.groupby('hotel', as_index = False).sum()
r
# Out:
#           hotel  previous_bookings_not_canceled
# 0  City Hotel    10501
# 1  Resort Hotel  5867

# %%
r['previous_bookings_not_canceled'].apply(lambda x: x / 16368)
# Out:
# 0   0.64
# 1   0.36
# Name: previous_bookings_not_canceled, dtype: float64

# %%
fig,ax = plt.subplots()
sns.barplot( x = 'hotel', y = 'previous_bookings_not_canceled',  data = r)

# %% [markdown]
# #### 64% of city hotel have a record of previous_bookings_not_canceled while Resort hotel have a record of 36% of previous_bookings_not_canceled

# %%
rg = df[['booking_changes', 'hotel']]
r = rg.groupby('hotel', as_index = False).mean()
r
# Out:
#           hotel  booking_changes
# 0  City Hotel   0.19
# 1  Resort Hotel 0.29

# %% [markdown]
# #### On average resort hotel have more booking cahanges compare to city hotel

# %%
rg = df[['days_in_waiting_list', 'hotel']]
r = rg.groupby('hotel', as_index = False).mean()
r
# Out:
#           hotel  days_in_waiting_list
# 0  City Hotel   3.23
# 1  Resort Hotel 0.53

# %% [markdown]
# #### From the above result Resort Hotel have the lowest days in waiting list. meaning they answer their customers faster?

# %%
rg = df[['total_of_special_requests', 'hotel']]
r = rg.groupby('hotel', as_index = False).mean()
r
# Out:
#           hotel  total_of_special_requests
# 0  City Hotel   0.55
# 1  Resort Hotel 0.62

# %% [markdown]
# #### On average The amount of total special requests for Resort Hotel is slighly higher than City Hotel

# %%
rg = df[['stay_days', 'hotel']]
r = rg.groupby('hotel', as_index = False).mean()
r
# Out:
#           hotel  stay_days
# 0  City Hotel   2.98
# 1  Resort Hotel 4.32

# %% [markdown]
# #### On average the number of days stayed in resort hotel is higher than City Hotel

# %%
rg = df[['people', 'hotel']]
r = rg.groupby('hotel', as_index = False).mean()
r
# Out:
#           hotel  people
# 0  City Hotel   1.95
# 1  Resort Hotel 2.01

# %% [markdown]
# #### On average the number of people that stays in Resort hotel is slightly higher than City hotel

# %%
rg = df[['nights', 'hotel']]
r = rg.groupby('hotel', as_index = False).mean()
r
# Out:
#           hotel  nights
# 0  City Hotel   2.98
# 1  Resort Hotel 4.32

# %% [markdown]
# #### The nights spent in Resort hotel is higher compare to the nights spent in City hotel on Average

# %%
import datetime
from dateutil import parser

# %%
parser.parse('2010-11 January').strftime('%A')
# Out:
# 'Monday'

# %%
df['arrival_date'] = df['arrival_date_year'].astype(str) + ',' + df['arrival_date_month'] + ' ' + df['arrival_date_day_of_month'].astype(str)

# %%
df['arrival_date']
# Out:
# 0         2015,July 1
# 1         2015,July 1
# 2         2015,July 1
# 3         2015,July 1
# 4         2015,July 1
#              ...
# 119385    2017,August 30
# 119386    2017,August 31
# 119387    2017,August 31
# 119388    2017,August 31
# 119389    2017,August 29
# Name: arrival_date, Length: 119390, dtype: object

# %%
df['arrival'] = df['arrival_date'].apply( lambda x : parser.parse(x).strftime("%A"))

# %%
r = df['arrival'].value_counts().to_frame().reset_index().rename(columns = {'index':'day', 'arrival':'NO'})
r
# Out:
#          day     NO
# 0  Friday     19631
# 1  Thursday   19254
# 2  Monday     18171
# 3  Saturday   18055
# 4  Wednesday  16139
# 5  Sunday     14141
# 6  Tuesday    13999

# %%
fig,ax = plt.subplots()
sns.barplot( x = 'NO', y = 'day',  data = r)

# %% [markdown]
# #### As expected most check in were on Fridays while Tuesdays have the least days for check in

# %%
df['check_out_day'] = df['reservation_status_date'].apply( lambda x : parser.parse(x).strftime("%A"))

# %%
r = df['check_out_day'].value_counts().to_frame().reset_index().rename(columns = {'index':'check_out_day', 'check_out_day':'NO'})
r
# Out:
#   check_out_day     NO
# 0  Monday        18692
# 1  Friday        18471
# 2  Thursday      18141
# 3  Wednesday     17943
# 4  Tuesday       16731
# 5  Sunday        16488
# 6  Saturday      12924

# %%
fig,ax = plt.subplots()
sns.barplot( x = 'NO', y = 'check_out_day',  data = r)

# %% [markdown]
# #### Mondays have the most check outs follow closely by Fridays while Saturdays have the least Check out

# %%
df['reservation_status'].value_counts()
# Out:
# Check-Out    75166
# Canceled     43017
# No-Show      1207
# Name: reservation_status, dtype: int64

# %%
df['deposit_type'].value_counts()
# Out:
# No Deposit    104641
# Non Refund    14587
# Refundable    162
# Name: deposit_type, dtype: int64

# %%
rg = df[['adr', 'hotel']]
r = rg.groupby('hotel', as_index = False).mean()
r
# Out:
#           hotel    adr
# 0  City Hotel   105.30
# 1  Resort Hotel 94.95

# %%
fig,ax = plt.subplots()
sns.barplot( x = 'hotel', y = 'adr',  data = r)

# %% [markdown]
# #### City hotel on average have higher rates per night compare to Resort Hotel

# %%
df.head(5)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel  0            342        2015               July
# 1  Resort Hotel  0            737        2015               July
# 2  Resort Hotel  0            7          2015               July
# 3  Resort Hotel  0            13         2015               July
# 4  Resort Hotel  0            14         2015               July
#
#    arrival_date_day_of_month  adults  children  babies meal  \
# 0  1                          2      0.00       0       BB
# 1  1                          2      0.00       0       BB
# 2  1                          1      0.00       0       BB
# 3  1                          1      0.00       0       BB
# 4  1                          2      0.00       0       BB
#
#    is_repeated_guest  previous_cancellations  previous_bookings_not_canceled  \
# 0  0                  0                       0
# 1  0                  0                       0
# ...

# %%
fig,ax = plt.subplots()
ax.scatter(y = df['adults'] , x = df['adr'] , color = PLOT_COLORS[2], edgecolors = '#000000', linewidths = 0.5)
ax.set(ylabel = 'adults', xlabel = 'adr')
# Out:
# [Text(0, 0.5, 'adults'), Text(0.5, 0, 'adr')]

# %%
h_labels = [x.replace('_', ' ').title() for x in list(df.select_dtypes(include = ['number', 'bool']).columns.values)]
fig,ax = plt.subplots(figsize = (10,10))
sns.heatmap(df.corr(), annot = True, xticklabels=h_labels, yticklabels= h_labels, cmap = sns.cubehelix_palette(as_cmap = True), ax = ax)

# %%
fig,ax = plt.subplots()
ax.scatter(y = df['adults'] , x = df['people'] , color = PLOT_COLORS[2], edgecolors = '#000000', linewidths = 0.5)
ax.set(ylabel = 'adults', xlabel = 'people')
# Out:
# [Text(0, 0.5, 'adults'), Text(0.5, 0, 'people')]
